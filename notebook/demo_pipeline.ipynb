# %% [markdown]
# # OmniReview - Final Pipeline Demo (GitHub Version)
#
# This notebook demonstrates the end-to-end execution of the OmniReview pipeline.
# It is designed to be run directly from GitHub without requiring Google Drive authentication.

# %%
# 1. Clone the repository and navigate into it
# !git clone https://github.com/JayashreeShrawan/OmniReview.git
# %cd OmniReview

# %%
# 2. Download and Unpack Backup Files (Data & Checkpoints)
# This will automatically download the heavy data and checkpoints zip file
# !pip install gdown
# !gdown --id 1yD4SyTP58gV9e_Mbze8DG2BY-l6UJ88r -O omnireview_backup.zip
# !unzip -o omnireview_backup.zip -d .
# !cp -r omnireview_backup/data/* data/ 2>/dev/null || true
# !cp -r omnireview_backup/checkpoints/* checkpoints/ 2>/dev/null || true

# %%
# 3. Install Requirements and Fix Colab Environment
# !pip install --upgrade torchao
# !pip install -r requirements.txt

# %%
# 4. Generate 10 sample reviews
# !python src/model_runner.py --samples 10

# %%
# 5. Display the generated samples
with open('outputs/samples.txt', 'r') as f:
    print(f.read())
